# %%
#define subtraction function of a - b

def subtract(a,b):
    return (a-b)

# %%
print(subtract(15, 5))
print(subtract(11,1))
print(subtract(19, 5))

# %%
def distance_from_zero(x):
    return abs(subtract(x,0))

print(distance_from_zero(9))
